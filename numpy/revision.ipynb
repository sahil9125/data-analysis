# %%
import numpy as np

# %%
list = [12,3,4]
arr =np.array(list)
print(arr.ndim)
print(arr)
# Out:
# 1
# [12  3  4]

# %%
print(np.eye(3))
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
print(np.zeros(2,3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(np.zeros(2,3))
#
# TypeError: Cannot interpret '3' as a data type
