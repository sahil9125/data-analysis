# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 2.4.4

# %%
arr = np.array([1,2,3,4])
print(arr)
print(type(arr))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4])
print(arr)
print(type(arr))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
import numpy as np

# %% [raw]
# print(np.__version__)

# %%
list=[1,2,3] #list
print(list)
print(type(list))
# Out:
# [1, 2, 3]
# <class 'list'>

# %%
arr_list = np.array(list)
print(arr_list)  #array  1d array h!
# Out:
# [1 2 3]

# %%
print(type(arr_list))
# Out:
# <class 'numpy.ndarray'>

# %%
list1 = [1,2,3]
list2 = [4,5,6]
arr_list1 =np.array([list1,list2])
print(arr_list1) # [[1,2,3][4,5,6]]  # [[,double mtlb 2d array
print(type(arr_list1))
# Out:
# [[1 2 3]
#  [4 5 6]]
# <class 'numpy.ndarray'>

# %%
# axix 0 - row upper se neeche
#axis 1 - columns baaye se daye
#2 rows
#3columns
#arr[0][0] = 1
#arr[1][2] = 6
#pahela index = row
#dusra index = column

# %%
list1 =[1,2,3]
list2 = [4,5,6]
list3 = [7,8,9]
arr_list2 = np.array([[list1,list2,list3]])
print(arr_list2)
print(type(arr_list2)) #3d array [[[
# Out:
# [[[1 2 3]
#   [4 5 6]
#   [7 8 9]]]
# <class 'numpy.ndarray'>

# %%
print(arr_list2.ndim) #  find dimensional .ndim
# Out:
# 3

# %%
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
