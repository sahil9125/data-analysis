# %%
import pandas as pd
data = pd.Series([10,20,30],index = [ 1 ,2 ,3])
print(data)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
df = pd.DataFrame({
'a':['ram','wedw'],
'b':['moahn','edwd'],
 'c':['syam','wfe']
})
print(df)
# Out:
#       a      b     c
# 0   ram  moahn  syam
# 1  wedw   edwd   wfe

# %%
df.head(1)
# Out:
#      a      b     c
# 0  ram  moahn  syam

# %%
df.tail()
# Out:
#       a      b     c
# 0   ram  moahn  syam
# 1  wedw   edwd   wfe

# %%
df.rename(columns={'c':'d'}, inplace = True)
print(df)
# Out:
#       a      b     d
# 0   ram  moahn  syam
# 1  wedw   edwd   wfe

# %%
df
# Out:
#       a      b     d
# 0   ram  moahn  syam
# 1  wedw   edwd   wfe

# %%
df.info
# Out:
# <bound method DataFrame.info of       a      b     d
# 0   ram  moahn  syam
# 1  wedw   edwd   wfe>

# %%
df['e'] = [10,20]
df
# Out:
#       a      b     d   e
# 0   ram  moahn  syam  10
# 1  wedw   edwd   wfe  20

# %%
df['e']>=18
# Out:
# 0    False
# 1     True
# Name: e, dtype: bool

# %%
df[df['e']>=18]
# Out:
#       a     b    d   e
# 1  wedw  edwd  wfe  20

# %%
df.where(df['e']>=18)
# Out:
#       a     b    d     e
# 0   NaN   NaN  NaN   NaN
# 1  wedw  edwd  wfe  20.0

# %%
df.loc[len(df)]=['mohn','ssd','scs',28]
df
# Out:
#       a      b     d   e
# 0   ram  moahn  syam  10
# 1  wedw   edwd   wfe  20
# 2  mohn    ssd   scs  28
# 3  mohn    ssd   scs  28

# %%
df.drop(3,axis=0)
# Out:
#       a      b     d   e
# 0   ram  moahn  syam  10
# 1  wedw   edwd   wfe  20
# 2  mohn    ssd   scs  28

# %%
import pandas as pd

# %%
data = {
    'name': ['shaym','mohan','lovekush'],
    'age' : [12,25,20],
    'salary': [120000,29000,32000]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#        name  age  salary
# 0     shaym   12  120000
# 1     mohan   25   29000
# 2  lovekush   20   32000

# %%
df.rename(columns={'salary':'monthly_salary'},inplace=True)

# %%
df
# Out:
#        name  age  monthly_salary
# 0     shaym   12          120000
# 1     mohan   25           29000
# 2  lovekush   20           32000

# %%
df.describe()
# Out:
#              age  monthly_salary
# count   3.000000        3.000000
# mean   19.000000    60333.333333
# std     6.557439    51694.616096
# min    12.000000    29000.000000
# 25%    16.000000    30500.000000
# 50%    20.000000    32000.000000
# 75%    22.500000    76000.000000
# max    25.000000   120000.000000
