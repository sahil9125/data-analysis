# %%
import pandas as pd
data = pd.Series([10,20,30],index = [ 1 ,2 ,3])
print(data)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
df = pd.DataFrame({
'a':['ram','wedw'],
'b':['moahn','edwd'],
 'c':['syam','wfe']
})
print(df)
# Out:
#       a      b     c
# 0   ram  moahn  syam
# 1  wedw   edwd   wfe

# %%
df.head(1)
# Out:
#      a      b     c
# 0  ram  moahn  syam

# %%
df.tail()
# Out:
#       a      b     c
# 0   ram  moahn  syam
# 1  wedw   edwd   wfe

# %%
df.rename(columns={'c':'d'}, inplace = True)
print(df)
# Out:
#       a      b     d
# 0   ram  moahn  syam
# 1  wedw   edwd   wfe

# %%
df
# Out:
#       a      b     d
# 0   ram  moahn  syam
# 1  wedw   edwd   wfe

# %%
df.info
# Out:
# <bound method DataFrame.info of       a      b     d
# 0   ram  moahn  syam
# 1  wedw   edwd   wfe>

# %%
df['e'] = [10,20]
df
# Out:
#       a      b     d   e
# 0   ram  moahn  syam  10
# 1  wedw   edwd   wfe  20

# %%
df['e']>=18
# Out:
# 0    False
# 1     True
# Name: e, dtype: bool

# %%
df[df['e']>=18]
# Out:
#       a     b    d   e
# 1  wedw  edwd  wfe  20

# %%
df.where(df['e']>=18)
# Out:
#       a     b    d     e
# 0   NaN   NaN  NaN   NaN
# 1  wedw  edwd  wfe  20.0

# %%
df.loc[len(df)]=['mohn','ssd','scs',28]
df
# Out:
#       a      b     d   e
# 0   ram  moahn  syam  10
# 1  wedw   edwd   wfe  20
# 2  mohn    ssd   scs  28
# 3  mohn    ssd   scs  28

# %%
df.drop(3,axis=0)
# Out:
#       a      b     d   e
# 0   ram  moahn  syam  10
# 1  wedw   edwd   wfe  20
# 2  mohn    ssd   scs  28
